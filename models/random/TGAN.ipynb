# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.io as io
from torch.optim import Adam, RMSprop
from torch.utils.data import DataLoader
from UCF101Loader import UCF101
from itertools import repeat

# %%
class LatentTemporalGenerator(nn.Module):
    def __init__(self):
        super().__init__()
        self.dc0 = nn.ConvTranspose1d(100, 512, 1, 1, 0)
        self.dc1 = nn.ConvTranspose1d(512, 256, 4, 2, 1) 
        self.dc2 = nn.ConvTranspose1d(256, 128, 4, 2, 1)
        self.dc3 = nn.ConvTranspose1d(128, 128, 4, 2, 1)
        self.dc4 = nn.ConvTranspose1d(128, 100, 4, 2, 1)
        self.bn0 = nn.BatchNorm1d(512)
        self.bn1 = nn.BatchNorm1d(256)
        self.bn2 = nn.BatchNorm1d(128)
        self.bn3 = nn.BatchNorm1d(128)
    
    def forward(self, z0):
        h = z0.view(z0.size(0),-1, 1)
        h = F.relu(self.bn0(self.dc0(h)))
        h = F.relu(self.bn1(self.dc1(h)))
        h = F.relu(self.bn2(self.dc2(h)))
        h = F.relu(self.bn3(self.dc3(h)))
        zT = torch.tanh(self.dc4(h))
        return zT

# %%
class VideoGenerator(nn.Module):
    def __init__(self, conv_ch=512):
        super().__init__()
        self.ch = conv_ch
        self.latent_dim = 256 * 4*4
        
        self.zTGen = LatentTemporalGenerator()
        
        self.lz0 = nn.Linear(100, self.latent_dim)
        self.lzT = nn.Linear(100, self.latent_dim)
        self.dc1 = nn.ConvTranspose2d(conv_ch, conv_ch // 2, 4, 2, 1)
        self.dc2 = nn.ConvTranspose2d(conv_ch // 2, conv_ch // 4, 4, 2, 1)
        self.dc3 = nn.ConvTranspose2d(conv_ch // 4, conv_ch // 8, 4, 2, 1)
        self.dc4 = nn.ConvTranspose2d(conv_ch // 8, conv_ch // 16, 4, 2, 1)
        self.dc5 = nn.ConvTranspose2d(conv_ch // 16, 3, 3, 1, 1)
        
        self.bn0s = nn.BatchNorm1d(self.latent_dim)
        self.bn0f = nn.BatchNorm1d(self.latent_dim)
        self.bn1 = nn.BatchNorm2d(conv_ch // 2)
        self.bn2 = nn.BatchNorm2d(conv_ch // 4)
        self.bn3 = nn.BatchNorm2d(conv_ch // 8)
        self.bn4 = nn.BatchNorm2d(conv_ch // 16)
        
    def forward(self, z0):
        zT = self.zTGen(z0)
        B = z0.shape[0]
        #z0 [B, 100] -> [B, 1, 100] -> [B, 16, 100], [B*16, 100]
        z0 = z0.unsqueeze(1).repeat(1, 16, 1).contiguous().view(B*16, 100)
        #zT [B, 100, 16] -> [B, 16, 100] -> [B*16, 100]
        zT = zT.permute(0, 2, 1).contiguous().view(B*16, 100)
        
        n = z0.shape[0]
        h_z0 = (F.relu(self.bn0s(self.lz0(z0))).view(n, self.ch // 2, 4, 4))
        h_zT = (F.relu(self.bn0f(self.lzT(zT)))).view(n, self.ch // 2, 4, 4)
        h = torch.cat((h_z0, h_zT), 1)
        h = F.relu(self.bn1(self.dc1(h)))
        h = F.relu(self.bn2(self.dc2(h)))
        h = F.relu(self.bn3(self.dc3(h)))
        h = F.relu(self.bn4(self.dc4(h)))
        x = torch.tanh(self.dc5(h)).view(B, 16, 3, 64, 64)
        return x

# %%
class Discriminator(nn.Module):
    def __init__(self, sequence_first=True, mid_ch=64):
        super().__init__()
        self.sequence_first=True

        self.c0 = nn.Conv3d(3, mid_ch, 4, 2, 1)
        self.c1 = nn.Conv3d(mid_ch, mid_ch * 2, 4, 2, 1)
        self.c2 = nn.Conv3d(mid_ch * 2, mid_ch * 4, 4, 2, 1)
        self.c3 = nn.Conv3d(mid_ch * 4, mid_ch * 8, 4, 2, 1)
        self.bn0 = nn.BatchNorm3d(mid_ch)
        self.bn1 = nn.BatchNorm3d(mid_ch * 2)
        self.bn2 = nn.BatchNorm3d(mid_ch * 4)
        self.bn3 = nn.BatchNorm3d(mid_ch * 8)

    def forward(self, x):
        if self.sequence_first:
            x = x.permute(0, 2, 1, 3, 4)

        h = F.leaky_relu(self.c0(x))
        h = F.leaky_relu(self.bn1(self.c1(h)))
        h = F.leaky_relu(self.bn2(self.c2(h)))
        h = F.leaky_relu(self.bn3(self.c3(h)))
        h = h.view(h.size(0), -1)
        return torch.mean(h, 1)

# %%
def tensorToVideo(t, epoch, const=True):
    os.makedirs('Video {}/{}'.format('Constant' if const else 'Random', epoch), exist_ok=True)
    t = (t.permute(0, 1, 3, 4, 2)+1) * 255 / 2
    for i in range(t.shape[0]):
        io.write_video('Video {}/{}/{}.mp4'.format('Constant' if const else 'Random', epoch, i), t[i], 25)

# %%
epochs = 1000
batch_size = 64
n_disc = 5
n_steps = 1000
constant_noise = torch.randn([64, 100]).cuda()
c = 1


g = VideoGenerator().cuda()
d = Discriminator().cuda()
g_optim = RMSprop(g.parameters(), lr=5e-5)
d_optim = RMSprop(d.parameters(), lr=5e-5)
loader = DataLoader(UCF101(), batch_size=batch_size, shuffle=True, drop_last=True)

# %%
def data_gen(data_loader):
    for loader in repeat(data_loader):
        for data in loader:
            yield data

# %%
loader = data_gen(loader)

# %%
for i, (X, y) in enumerate(loader):
    i += 1
    print(i)
    z = torch.randn([64, 100]).cuda()
    pred_g = g(z)
    pred_dx = d(X.cuda())
    pred_dg = d(pred_g)
    loss_d = -torch.mean(pred_dx - pred_dg)
    loss_d.backward()

    d_optim.step()
    d_optim.zero_grad()
    g_optim.zero_grad()
    
    for p in d.parameters():
        p.data.clamp_(-c, c)
    
    print('Discriminator Loss: ', loss_d)
    
    if i % n_disc == 0:
        z = torch.randn([64, 100]).cuda()
        pred_g = g(z)
        with torch.no_grad():
            pred_dg = d(pred_g)
        loss_g = -torch.mean(pred_dg)
        loss_g.backward()
        
        g_optim.step()
        print('Generator Loss: ', loss_g)
        
        if i % 25 == 0:
            tensorToVideo(g(z), i, const=False)
            tensorToVideo(g(constant_noise), i)
# Out:
# 1
# Discriminator Loss:  tensor(0.0072, device='cuda:0', grad_fn=<NegBackward>)
# 2
# Discriminator Loss:  tensor(-0.0003, device='cuda:0', grad_fn=<NegBackward>)
# 3
# Discriminator Loss:  tensor(-0.0010, device='cuda:0', grad_fn=<NegBackward>)
# 4
# Discriminator Loss:  tensor(-0.0016, device='cuda:0', grad_fn=<NegBackward>)
# 5
# Discriminator Loss:  tensor(-0.0020, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0185, device='cuda:0', grad_fn=<NegBackward>)
# 6
# Discriminator Loss:  tensor(-0.0021, device='cuda:0', grad_fn=<NegBackward>)
# 7
# Discriminator Loss:  tensor(-0.0024, device='cuda:0', grad_fn=<NegBackward>)
# 8
# Discriminator Loss:  tensor(-0.0028, device='cuda:0', grad_fn=<NegBackward>)
# 9
# Discriminator Loss:  tensor(-0.0030, device='cuda:0', grad_fn=<NegBackward>)
# 10
# Discriminator Loss:  tensor(-0.0032, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0184, device='cuda:0', grad_fn=<NegBackward>)
# 11
# Discriminator Loss:  tensor(-0.0019, device='cuda:0', grad_fn=<NegBackward>)
# 12
# Discriminator Loss:  tensor(-0.0022, device='cuda:0', grad_fn=<NegBackward>)
# 13
# Discriminator Loss:  tensor(-0.0029, device='cuda:0', grad_fn=<NegBackward>)
# 14
# Discriminator Loss:  tensor(-0.0031, device='cuda:0', grad_fn=<NegBackward>)
# 15
# Discriminator Loss:  tensor(-0.0033, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0183, device='cuda:0', grad_fn=<NegBackward>)
# 16
# Discriminator Loss:  tensor(-0.0033, device='cuda:0', grad_fn=<NegBackward>)
# 17
# Discriminator Loss:  tensor(-0.0035, device='cuda:0', grad_fn=<NegBackward>)
# 18
# Discriminator Loss:  tensor(-0.0039, device='cuda:0', grad_fn=<NegBackward>)
# 19
# Discriminator Loss:  tensor(-0.0039, device='cuda:0', grad_fn=<NegBackward>)
# 20
# Discriminator Loss:  tensor(-0.0032, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0180, device='cuda:0', grad_fn=<NegBackward>)
# 21
# Discriminator Loss:  tensor(-0.0040, device='cuda:0', grad_fn=<NegBackward>)
# 22
# Discriminator Loss:  tensor(-0.0042, device='cuda:0', grad_fn=<NegBackward>)
# 23
# Discriminator Loss:  tensor(-0.0046, device='cuda:0', grad_fn=<NegBackward>)
# 24
# Discriminator Loss:  tensor(-0.0047, device='cuda:0', grad_fn=<NegBackward>)
# 25
# Discriminator Loss:  tensor(-0.0038, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0183, device='cuda:0', grad_fn=<NegBackward>)
# 26
# Discriminator Loss:  tensor(-0.0026, device='cuda:0', grad_fn=<NegBackward>)
# 27
# Discriminator Loss:  tensor(-0.0029, device='cuda:0', grad_fn=<NegBackward>)
# 28
# Discriminator Loss:  tensor(-0.0034, device='cuda:0', grad_fn=<NegBackward>)
# 29
# Discriminator Loss:  tensor(-0.0037, device='cuda:0', grad_fn=<NegBackward>)
# 30
# Discriminator Loss:  tensor(-0.0040, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0188, device='cuda:0', grad_fn=<NegBackward>)
# 31
# Discriminator Loss:  tensor(-0.0035, device='cuda:0', grad_fn=<NegBackward>)
# 32
# Discriminator Loss:  tensor(-0.0037, device='cuda:0', grad_fn=<NegBackward>)
# 33
# Discriminator Loss:  tensor(-0.0039, device='cuda:0', grad_fn=<NegBackward>)
# 34
# Discriminator Loss:  tensor(-0.0041, device='cuda:0', grad_fn=<NegBackward>)
# 35
# Discriminator Loss:  tensor(-0.0044, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0185, device='cuda:0', grad_fn=<NegBackward>)
# 36
# Discriminator Loss:  tensor(-0.0039, device='cuda:0', grad_fn=<NegBackward>)
# 37
# Discriminator Loss:  tensor(-0.0040, device='cuda:0', grad_fn=<NegBackward>)
# 38
# Discriminator Loss:  tensor(-0.0048, device='cuda:0', grad_fn=<NegBackward>)
# 39
# Discriminator Loss:  tensor(-0.0050, device='cuda:0', grad_fn=<NegBackward>)
# 40
# Discriminator Loss:  tensor(-0.0050, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0181, device='cuda:0', grad_fn=<NegBackward>)
# 41
# Discriminator Loss:  tensor(-0.0046, device='cuda:0', grad_fn=<NegBackward>)
# 42
# Discriminator Loss:  tensor(-0.0046, device='cuda:0', grad_fn=<NegBackward>)
# 43
# Discriminator Loss:  tensor(-0.0051, device='cuda:0', grad_fn=<NegBackward>)
# 44
# Discriminator Loss:  tensor(-0.0056, device='cuda:0', grad_fn=<NegBackward>)
# 45
# Discriminator Loss:  tensor(-0.0053, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0177, device='cuda:0', grad_fn=<NegBackward>)
# 46
# Discriminator Loss:  tensor(-0.0043, device='cuda:0', grad_fn=<NegBackward>)
# 47
# Discriminator Loss:  tensor(-0.0047, device='cuda:0', grad_fn=<NegBackward>)
# 48
# Discriminator Loss:  tensor(-0.0058, device='cuda:0', grad_fn=<NegBackward>)
# 49
# Discriminator Loss:  tensor(-0.0062, device='cuda:0', grad_fn=<NegBackward>)
# 50
# Discriminator Loss:  tensor(-0.0061, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0173, device='cuda:0', grad_fn=<NegBackward>)
# 51
# Discriminator Loss:  tensor(-0.0052, device='cuda:0', grad_fn=<NegBackward>)
# 52
# Discriminator Loss:  tensor(-0.0053, device='cuda:0', grad_fn=<NegBackward>)
# 53
# Discriminator Loss:  tensor(-0.0065, device='cuda:0', grad_fn=<NegBackward>)
# 54
# Discriminator Loss:  tensor(-0.0070, device='cuda:0', grad_fn=<NegBackward>)
# 55
# Discriminator Loss:  tensor(-0.0069, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0167, device='cuda:0', grad_fn=<NegBackward>)
# 56
# Discriminator Loss:  tensor(-0.0062, device='cuda:0', grad_fn=<NegBackward>)
# 57
# Discriminator Loss:  tensor(-0.0064, device='cuda:0', grad_fn=<NegBackward>)
# 58
# Discriminator Loss:  tensor(-0.0073, device='cuda:0', grad_fn=<NegBackward>)
# 59
# Discriminator Loss:  tensor(-0.0071, device='cuda:0', grad_fn=<NegBackward>)
# 60
# Discriminator Loss:  tensor(-0.0066, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0164, device='cuda:0', grad_fn=<NegBackward>)
# 61
# Discriminator Loss:  tensor(-0.0066, device='cuda:0', grad_fn=<NegBackward>)
# 62
# Discriminator Loss:  tensor(-0.0066, device='cuda:0', grad_fn=<NegBackward>)
# 63
# Discriminator Loss:  tensor(-0.0078, device='cuda:0', grad_fn=<NegBackward>)
# 64
# Discriminator Loss:  tensor(-0.0083, device='cuda:0', grad_fn=<NegBackward>)
# 65
# Discriminator Loss:  tensor(-0.0082, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0158, device='cuda:0', grad_fn=<NegBackward>)
# 66
# Discriminator Loss:  tensor(-0.0075, device='cuda:0', grad_fn=<NegBackward>)
# 67
# Discriminator Loss:  tensor(-0.0076, device='cuda:0', grad_fn=<NegBackward>)
# 68
# Discriminator Loss:  tensor(-0.0083, device='cuda:0', grad_fn=<NegBackward>)
# 69
# Discriminator Loss:  tensor(-0.0086, device='cuda:0', grad_fn=<NegBackward>)
# 70
# Discriminator Loss:  tensor(-0.0085, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0160, device='cuda:0', grad_fn=<NegBackward>)
# 71
# Discriminator Loss:  tensor(-0.0067, device='cuda:0', grad_fn=<NegBackward>)
# 72
# Discriminator Loss:  tensor(-0.0069, device='cuda:0', grad_fn=<NegBackward>)
# 73
# Discriminator Loss:  tensor(-0.0083, device='cuda:0', grad_fn=<NegBackward>)
# 74
# Discriminator Loss:  tensor(-0.0090, device='cuda:0', grad_fn=<NegBackward>)
# 75
# Discriminator Loss:  tensor(-0.0090, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0157, device='cuda:0', grad_fn=<NegBackward>)
# 76
# Discriminator Loss:  tensor(-0.0071, device='cuda:0', grad_fn=<NegBackward>)
# 77
# Discriminator Loss:  tensor(-0.0073, device='cuda:0', grad_fn=<NegBackward>)
# 78
# Discriminator Loss:  tensor(-0.0089, device='cuda:0', grad_fn=<NegBackward>)
# 79
# Discriminator Loss:  tensor(-0.0088, device='cuda:0', grad_fn=<NegBackward>)
# 80
# Discriminator Loss:  tensor(-0.0086, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0155, device='cuda:0', grad_fn=<NegBackward>)
# 81
# Discriminator Loss:  tensor(-0.0068, device='cuda:0', grad_fn=<NegBackward>)
# 82
# Discriminator Loss:  tensor(-0.0071, device='cuda:0', grad_fn=<NegBackward>)
# 83
# Discriminator Loss:  tensor(-0.0088, device='cuda:0', grad_fn=<NegBackward>)
# 84
# Discriminator Loss:  tensor(-0.0093, device='cuda:0', grad_fn=<NegBackward>)
# 85
# Discriminator Loss:  tensor(-0.0090, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0152, device='cuda:0', grad_fn=<NegBackward>)
# 86
# Discriminator Loss:  tensor(-0.0071, device='cuda:0', grad_fn=<NegBackward>)
# 87
# Discriminator Loss:  tensor(-0.0070, device='cuda:0', grad_fn=<NegBackward>)
# 88
# Discriminator Loss:  tensor(-0.0088, device='cuda:0', grad_fn=<NegBackward>)
# 89
# Discriminator Loss:  tensor(-0.0093, device='cuda:0', grad_fn=<NegBackward>)
# 90
# Discriminator Loss:  tensor(-0.0086, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0151, device='cuda:0', grad_fn=<NegBackward>)
# 91
# Discriminator Loss:  tensor(-0.0088, device='cuda:0', grad_fn=<NegBackward>)
# 92
# Discriminator Loss:  tensor(-0.0091, device='cuda:0', grad_fn=<NegBackward>)
# 93
# Discriminator Loss:  tensor(-0.0100, device='cuda:0', grad_fn=<NegBackward>)
# 94
# Discriminator Loss:  tensor(-0.0100, device='cuda:0', grad_fn=<NegBackward>)
# 95
# Discriminator Loss:  tensor(-0.0100, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0148, device='cuda:0', grad_fn=<NegBackward>)
# 96
# Discriminator Loss:  tensor(-0.0092, device='cuda:0', grad_fn=<NegBackward>)
# 97
# Discriminator Loss:  tensor(-0.0095, device='cuda:0', grad_fn=<NegBackward>)
# 98
# Discriminator Loss:  tensor(-0.0103, device='cuda:0', grad_fn=<NegBackward>)
# 99
# Discriminator Loss:  tensor(-0.0102, device='cuda:0', grad_fn=<NegBackward>)
# 100
# Discriminator Loss:  tensor(-0.0104, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0145, device='cuda:0', grad_fn=<NegBackward>)
# 101
# Discriminator Loss:  tensor(-0.0099, device='cuda:0', grad_fn=<NegBackward>)
# 102
# Discriminator Loss:  tensor(-0.0101, device='cuda:0', grad_fn=<NegBackward>)
# 103
# Discriminator Loss:  tensor(-0.0108, device='cuda:0', grad_fn=<NegBackward>)
# 104
# Discriminator Loss:  tensor(-0.0104, device='cuda:0', grad_fn=<NegBackward>)
# 105
# Discriminator Loss:  tensor(-0.0104, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0148, device='cuda:0', grad_fn=<NegBackward>)
# 106
# Discriminator Loss:  tensor(-0.0095, device='cuda:0', grad_fn=<NegBackward>)
# 107
# Discriminator Loss:  tensor(-0.0097, device='cuda:0', grad_fn=<NegBackward>)
# 108
# Discriminator Loss:  tensor(-0.0107, device='cuda:0', grad_fn=<NegBackward>)
# 109
# Discriminator Loss:  tensor(-0.0108, device='cuda:0', grad_fn=<NegBackward>)
# 110
# Discriminator Loss:  tensor(-0.0109, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0144, device='cuda:0', grad_fn=<NegBackward>)
# 111
# Discriminator Loss:  tensor(-0.0106, device='cuda:0', grad_fn=<NegBackward>)
# 112
# Discriminator Loss:  tensor(-0.0105, device='cuda:0', grad_fn=<NegBackward>)
# 113
# Discriminator Loss:  tensor(-0.0111, device='cuda:0', grad_fn=<NegBackward>)
# 114
# Discriminator Loss:  tensor(-0.0110, device='cuda:0', grad_fn=<NegBackward>)
# 115
# Discriminator Loss:  tensor(-0.0111, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0143, device='cuda:0', grad_fn=<NegBackward>)
# 116
# Discriminator Loss:  tensor(-0.0108, device='cuda:0', grad_fn=<NegBackward>)
# 117
# Discriminator Loss:  tensor(-0.0107, device='cuda:0', grad_fn=<NegBackward>)
# 118
# Discriminator Loss:  tensor(-0.0111, device='cuda:0', grad_fn=<NegBackward>)
# 119
# Discriminator Loss:  tensor(-0.0111, device='cuda:0', grad_fn=<NegBackward>)
# 120
# Discriminator Loss:  tensor(-0.0112, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0142, device='cuda:0', grad_fn=<NegBackward>)
# 121
# Discriminator Loss:  tensor(-0.0106, device='cuda:0', grad_fn=<NegBackward>)
# 122
# Discriminator Loss:  tensor(-0.0107, device='cuda:0', grad_fn=<NegBackward>)
# 123
# Discriminator Loss:  tensor(-0.0114, device='cuda:0', grad_fn=<NegBackward>)
# 124
# Discriminator Loss:  tensor(-0.0112, device='cuda:0', grad_fn=<NegBackward>)
# 125
# Discriminator Loss:  tensor(-0.0114, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0144, device='cuda:0', grad_fn=<NegBackward>)
# 126
# Discriminator Loss:  tensor(-0.0105, device='cuda:0', grad_fn=<NegBackward>)
# 127
# Discriminator Loss:  tensor(-0.0109, device='cuda:0', grad_fn=<NegBackward>)
# 128
# Discriminator Loss:  tensor(-0.0113, device='cuda:0', grad_fn=<NegBackward>)
# 129
# Discriminator Loss:  tensor(-0.0114, device='cuda:0', grad_fn=<NegBackward>)
# 130
# Discriminator Loss:  tensor(-0.0115, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0144, device='cuda:0', grad_fn=<NegBackward>)
# 131
# Discriminator Loss:  tensor(-0.0108, device='cuda:0', grad_fn=<NegBackward>)
# 132
# Discriminator Loss:  tensor(-0.0109, device='cuda:0', grad_fn=<NegBackward>)
# 133
# Discriminator Loss:  tensor(-0.0116, device='cuda:0', grad_fn=<NegBackward>)
# 134
# Discriminator Loss:  tensor(-0.0114, device='cuda:0', grad_fn=<NegBackward>)
# 135
# Discriminator Loss:  tensor(-0.0115, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0143, device='cuda:0', grad_fn=<NegBackward>)
# 136
# Discriminator Loss:  tensor(-0.0109, device='cuda:0', grad_fn=<NegBackward>)
# 137
# Discriminator Loss:  tensor(-0.0108, device='cuda:0', grad_fn=<NegBackward>)
# 138
# Discriminator Loss:  tensor(-0.0115, device='cuda:0', grad_fn=<NegBackward>)
# 139
# Discriminator Loss:  tensor(-0.0116, device='cuda:0', grad_fn=<NegBackward>)
# 140
# Discriminator Loss:  tensor(-0.0116, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0143, device='cuda:0', grad_fn=<NegBackward>)
# 141
# Discriminator Loss:  tensor(-0.0106, device='cuda:0', grad_fn=<NegBackward>)
# 142
# Discriminator Loss:  tensor(-0.0107, device='cuda:0', grad_fn=<NegBackward>)
# 143
# Discriminator Loss:  tensor(-0.0119, device='cuda:0', grad_fn=<NegBackward>)
# 144
# Discriminator Loss:  tensor(-0.0117, device='cuda:0', grad_fn=<NegBackward>)
# 145
# Discriminator Loss:  tensor(-0.0118, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0142, device='cuda:0', grad_fn=<NegBackward>)
# 146
# Discriminator Loss:  tensor(-0.0112, device='cuda:0', grad_fn=<NegBackward>)
# 147
# Discriminator Loss:  tensor(-0.0113, device='cuda:0', grad_fn=<NegBackward>)
# 148
# Discriminator Loss:  tensor(-0.0120, device='cuda:0', grad_fn=<NegBackward>)
# 149
# Discriminator Loss:  tensor(-0.0117, device='cuda:0', grad_fn=<NegBackward>)
# 150
# Discriminator Loss:  tensor(-0.0118, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0143, device='cuda:0', grad_fn=<NegBackward>)
# 151
# Discriminator Loss:  tensor(-0.0111, device='cuda:0', grad_fn=<NegBackward>)
# 152
# Discriminator Loss:  tensor(-0.0114, device='cuda:0', grad_fn=<NegBackward>)
# 153
# Discriminator Loss:  tensor(-0.0120, device='cuda:0', grad_fn=<NegBackward>)
# 154
# Discriminator Loss:  tensor(-0.0120, device='cuda:0', grad_fn=<NegBackward>)
# 155
# Discriminator Loss:  tensor(-0.0118, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0142, device='cuda:0', grad_fn=<NegBackward>)
# 156
# Discriminator Loss:  tensor(-0.0114, device='cuda:0', grad_fn=<NegBackward>)
# 157
# Discriminator Loss:  tensor(-0.0115, device='cuda:0', grad_fn=<NegBackward>)
# 158
# Discriminator Loss:  tensor(-0.0123, device='cuda:0', grad_fn=<NegBackward>)
# 159
# Discriminator Loss:  tensor(-0.0122, device='cuda:0', grad_fn=<NegBackward>)
# 160
# Discriminator Loss:  tensor(-0.0119, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0141, device='cuda:0', grad_fn=<NegBackward>)
# 161
# Discriminator Loss:  tensor(-0.0120, device='cuda:0', grad_fn=<NegBackward>)
# 162
# Discriminator Loss:  tensor(-0.0120, device='cuda:0', grad_fn=<NegBackward>)
# 163
# Discriminator Loss:  tensor(-0.0123, device='cuda:0', grad_fn=<NegBackward>)
# 164
# Discriminator Loss:  tensor(-0.0123, device='cuda:0', grad_fn=<NegBackward>)
# 165
# Discriminator Loss:  tensor(-0.0122, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0140, device='cuda:0', grad_fn=<NegBackward>)
# 166
# Discriminator Loss:  tensor(-0.0120, device='cuda:0', grad_fn=<NegBackward>)
# 167
# Discriminator Loss:  tensor(-0.0120, device='cuda:0', grad_fn=<NegBackward>)
# 168
# Discriminator Loss:  tensor(-0.0124, device='cuda:0', grad_fn=<NegBackward>)
# 169
# Discriminator Loss:  tensor(-0.0123, device='cuda:0', grad_fn=<NegBackward>)
# 170
# Discriminator Loss:  tensor(-0.0124, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0139, device='cuda:0', grad_fn=<NegBackward>)
# 171
# Discriminator Loss:  tensor(-0.0122, device='cuda:0', grad_fn=<NegBackward>)
# 172
# Discriminator Loss:  tensor(-0.0125, device='cuda:0', grad_fn=<NegBackward>)
# 173
# Discriminator Loss:  tensor(-0.0124, device='cuda:0', grad_fn=<NegBackward>)
# 174
# Discriminator Loss:  tensor(-0.0125, device='cuda:0', grad_fn=<NegBackward>)
# 175
# Discriminator Loss:  tensor(-0.0125, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0139, device='cuda:0', grad_fn=<NegBackward>)
# 176
# Discriminator Loss:  tensor(-0.0124, device='cuda:0', grad_fn=<NegBackward>)
# 177
# Discriminator Loss:  tensor(-0.0124, device='cuda:0', grad_fn=<NegBackward>)
# 178
# Discriminator Loss:  tensor(-0.0125, device='cuda:0', grad_fn=<NegBackward>)
# 179
# Discriminator Loss:  tensor(-0.0126, device='cuda:0', grad_fn=<NegBackward>)
# 180
# Discriminator Loss:  tensor(-0.0127, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0139, device='cuda:0', grad_fn=<NegBackward>)
# 181
# Discriminator Loss:  tensor(-0.0125, device='cuda:0', grad_fn=<NegBackward>)
# 182
# Discriminator Loss:  tensor(-0.0126, device='cuda:0', grad_fn=<NegBackward>)
# 183
# Discriminator Loss:  tensor(-0.0127, device='cuda:0', grad_fn=<NegBackward>)
# 184
# Discriminator Loss:  tensor(-0.0128, device='cuda:0', grad_fn=<NegBackward>)
# 185
# Discriminator Loss:  tensor(-0.0128, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0139, device='cuda:0', grad_fn=<NegBackward>)
# 186
# Discriminator Loss:  tensor(-0.0124, device='cuda:0', grad_fn=<NegBackward>)
# 187
# Discriminator Loss:  tensor(-0.0124, device='cuda:0', grad_fn=<NegBackward>)
# 188
# Discriminator Loss:  tensor(-0.0126, device='cuda:0', grad_fn=<NegBackward>)
# 189
# Discriminator Loss:  tensor(-0.0127, device='cuda:0', grad_fn=<NegBackward>)
# 190
# Discriminator Loss:  tensor(-0.0129, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0140, device='cuda:0', grad_fn=<NegBackward>)
# 191
# Discriminator Loss:  tensor(-0.0126, device='cuda:0', grad_fn=<NegBackward>)
# 192
# Discriminator Loss:  tensor(-0.0126, device='cuda:0', grad_fn=<NegBackward>)
# 193
# Discriminator Loss:  tensor(-0.0129, device='cuda:0', grad_fn=<NegBackward>)
# 194
# Discriminator Loss:  tensor(-0.0129, device='cuda:0', grad_fn=<NegBackward>)
# 195
# Discriminator Loss:  tensor(-0.0128, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0139, device='cuda:0', grad_fn=<NegBackward>)
# 196
# Discriminator Loss:  tensor(-0.0127, device='cuda:0', grad_fn=<NegBackward>)
# 197
# Discriminator Loss:  tensor(-0.0128, device='cuda:0', grad_fn=<NegBackward>)
# 198
# Discriminator Loss:  tensor(-0.0132, device='cuda:0', grad_fn=<NegBackward>)
# 199
# Discriminator Loss:  tensor(-0.0130, device='cuda:0', grad_fn=<NegBackward>)
# 200
# Discriminator Loss:  tensor(-0.0131, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0138, device='cuda:0', grad_fn=<NegBackward>)
# 201
# Discriminator Loss:  tensor(-0.0129, device='cuda:0', grad_fn=<NegBackward>)
# 202
# Discriminator Loss:  tensor(-0.0129, device='cuda:0', grad_fn=<NegBackward>)
# 203
# Discriminator Loss:  tensor(-0.0132, device='cuda:0', grad_fn=<NegBackward>)
# 204
# Discriminator Loss:  tensor(-0.0131, device='cuda:0', grad_fn=<NegBackward>)
# 205
# Discriminator Loss:  tensor(-0.0131, device='cuda:0', grad_fn=<NegBackward>)
# Generator Loss:  tensor(-0.0138, device='cuda:0', grad_fn=<NegBackward>)
# 206
# Discriminator Loss:  tensor(-0.0129, device='cuda:0', grad_fn=<NegBackward>)
# 207
# Discriminator Loss:  tensor(-0.0126, device='cuda:0', grad_fn=<NegBackward>)
# 208
# Discriminator Loss:  tensor(-0.0134, device='cuda:0', grad_fn=<NegBackward>)
# 209
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-9e3ee0789208> in <module>()
#       6     pred_dx = d(X.cuda())
#       7     pred_dg = d(pred_g)
# ----> 8     loss_d = -torch.mean(pred_dx - pred_dg)
#       9     loss_d.backward()
#      10
#
# RuntimeError: The size of tensor a (8) must match the size of tensor b (64) at non-singleton dimension 0
