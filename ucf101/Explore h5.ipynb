# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from UCF101DatasetTGAN import UCF101

# %%
conf = "C:/Video Datasets/UCF101_tgan/ucf101_train_pd.pkl"
dset = "D:/Video Datasets/ucf101_64px_tgan/train.h5"

# %%
data = UCF101(dset, conf)
# Out:
#          category  end  group  scene  start
# 0  ApplyEyeMakeup  121      8      1      0
# 1  ApplyEyeMakeup  239      8      2    121
# 2  ApplyEyeMakeup  386      8      3    239
# 3  ApplyEyeMakeup  611      8      4    386
# 4  ApplyEyeMakeup  888      8      5    611

# %%
data.__getitem__(1).shape
# Out:
# torch.Size([16, 3, 64, 64])

# %%
plt.imshow(data.__getitem__(8890)[0].numpy().transpose(1,2,0)/2 + 0.5)
